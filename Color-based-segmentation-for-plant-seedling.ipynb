png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/97.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/277.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/147.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/259.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/260.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/120.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/193.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/327.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/160.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/339.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/176.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/87.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/58.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/309.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/324.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/284.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/139.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/336.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/179.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/297.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/188.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/236.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/143.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/248.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/174.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/230.png
# /kaggle/input/v2-plant-seedlings-dataset/Cleavers/63.png
# /kaggle/input/v2-plant-seedlings-dataset/Maize/240.png
# /kaggle/input/v2-plant-seedlings-dataset/Maize/145.png
# /kaggle/input/v2-plant-seedlings-dataset/Maize/222.png
# /kaggle/input/v2-plant-seedlings-dataset/Maize/10.png
# /kaggle/input/v2-plant-seedlings-dataset/Maize/49.png
# /kaggle/input/v2-plant-seedlings-dataset/Maize/61.png
# /kaggle/input/v2-plant-seedlings-dataset/Maize/76.png
# /kaggle/input/v2-plant-seedlings-dataset/Maize/17.png
# /kaggle/input/v2-plant-seedlings-dataset/Maize/199.png
# /kaggle/input/v2-plant-seedlings-dataset/Maize/128.png
# /kaggle/input/v2-plant-seedlings-dataset/Maize/78.png
# /kaggle/input/v2-plant-seedlings-dataset/Maize/242.png
# /kaggle/input/v2-plant-seedlings-dataset/Maize/244.png
# /kaggle/input/v2-plant-seedlings-dataset/Maize/95.png
# /kaggle/input/v2-plant-seedlings-dataset/Maize/83.png
# /kaggle/input/v2-plant-seedlings-dataset/Maize/237.png
# /kaggle/input/v2-plant-seedlings-dataset/Maize/65.png
# /kaggle/input/v2-plant-seedlings-dataset/Maize/168.png
# ...
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/202.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/137.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/35.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/150.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/161.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/7.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/114.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/201.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/151.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/207.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/96.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/225.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/29.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/105.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/140.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/113.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/54.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/33.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/4.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/163.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/241.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/118.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/112.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/3.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/245.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/261.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/75.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/217.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/71.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/166.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/216.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/227.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/18.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/89.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/40.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/42.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/175.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/219.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/255.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/223.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/210.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/123.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/51.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/266.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/41.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/56.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/246.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/93.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/101.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/185.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/11.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/221.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/159.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/91.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/268.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/264.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/189.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/165.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/262.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/158.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/203.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/213.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/103.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/34.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/253.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/167.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/37.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/108.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/178.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/19.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/272.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/263.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/187.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/180.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/141.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/197.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/77.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/265.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/184.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/64.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/48.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/144.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/60.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/220.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/204.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/130.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/191.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/233.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/69.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/67.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/6.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/239.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/247.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/100.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/53.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/173.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/23.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/107.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/127.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/104.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/27.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/250.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/235.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/21.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/156.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/200.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/26.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/254.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/32.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/8.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/66.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/72.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/86.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/215.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/121.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/157.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/198.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/36.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/85.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/46.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/31.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/162.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/172.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/117.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/45.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/243.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/134.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/129.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/55.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/125.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/132.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/81.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/192.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/43.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/13.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/25.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/47.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/5.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/258.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/22.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/209.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/218.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/208.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/226.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/20.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/131.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/109.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/273.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/212.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/186.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/30.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/79.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/119.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/232.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/154.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/14.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/170.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/214.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/169.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/251.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/269.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/249.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/50.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/171.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/111.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/211.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/138.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/98.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/224.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/9.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/12.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/2.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/39.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/228.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/94.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/80.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/256.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/1.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/106.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/90.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/274.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/152.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/133.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/196.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/205.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/110.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/70.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/229.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/164.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/68.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/194.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/16.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/231.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/74.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/57.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/122.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/135.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/270.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/149.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/99.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/146.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/28.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/183.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/252.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/153.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/238.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/126.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/275.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/271.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/177.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/115.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/24.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/82.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/155.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/148.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/206.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/102.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/195.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/84.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/142.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/182.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/38.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/73.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/97.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/147.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/259.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/260.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/15.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/120.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/193.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/160.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/176.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/87.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/58.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/139.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/179.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/188.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/236.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/143.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/248.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/174.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/230.png
# /kaggle/input/v2-plant-seedlings-dataset/Shepherd’s Purse/63.png

# %%
# %env JOBLIB_TEMP_FOLDER=/tmp

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib import colors
import seaborn as sns
sns.set_style('whitegrid')

from PIL import Image
from imageio import imread
import imageio
import skimage
import skimage.io
import skimage.transform
from imageio import imread


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score

from skimage.morphology import closing, disk, opening
import random
import time
import copy
from tqdm import tqdm_notebook as tqdm
from os import listdir
import keras
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, ReduceLROnPlateau

from keras import backend as K
from keras.models import Sequential
from keras.models import Model
from keras.layers import Activation
from keras.layers.core import Dense, Flatten
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Dropout
from keras.layers.convolutional import *
from keras.callbacks import ModelCheckpoint
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input
from keras.applications.inception_v3 import decode_predictions
from sklearn.metrics import confusion_matrix
from sklearn.metrics import average_precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from keras.models import model_from_json
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras import optimizers
from keras.models import Sequential, Model 
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.utils import np_utils
from keras.optimizers import SGD

from IPython.core.display import display, HTML
from PIL import Image
# Out:
# env: JOBLIB_TEMP_FOLDER=/tmp

# %%
from io import BytesIO
import base64

from os import listdir
from skimage.segmentation import mark_boundaries

import cv2

# %%
Directory='../input/v2-plant-seedlings-dataset/nonsegmentedv2/'
subfolders = listdir(Directory)
print(os.listdir('../input/v2-plant-seedlings-dataset/nonsegmentedv2/'))
# Out:
# ['Sugar beet', 'Cleavers', 'Maize', 'Black-grass', 'Scentless Mayweed', 'Small-flowered Cranesbill', 'Loose Silky-bent', 'Common Chickweed', 'Common wheat', 'Fat Hen', 'Charlock', 'Shepherd’s Purse']

# %%
sfc="Small-flowered Cranesbill"
plt.figure(figsize=(15,12))

for n in range(12):
        folder=subfolders[n]
        plt.subplot(3,4,n+1)
        files = listdir(Directory + folder + "/") 
        image=cv2.imread(Directory + folder + "/" + files[n+221])
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        plt.axis("off")
        plt.title(folder, fontsize=14, weight='bold')

# %% [markdown]
# 1. After visualizing the images, we have an idea of the how to deal with this project:
# 1.
# 1. Aim: Classify the plant species images so that the machine distinguishes between crop seedlings and weed.
# 1.
# 1. Challenge: The images include some stones in the background, we don't want the machine to learn the stones pixels and base its prediction on all the components of the image: seedlings + stones
# 1.
# 1. Solution: Color-based segmentation: Keep just the green color pixels = Keep just the seedlings pixels
# 1.
# 1. Excepted result: Clean plant images without stones in the background. Ready to be fed to the model.

# %% [markdown]
# 1. Image preprocessing:¶
# 1. 2.1 Import the images
# 1. We start our image preprocessing by importing a Small-flowered Cranesbill image as a test image.

# %%
p1 = cv2.imread('/kaggle/input/v2-plant-seedlings-dataset/nonsegmentedv2/Small-flowered Cranesbill/135.png')
p1 = cv2.cvtColor(p1, cv2.COLOR_BGR2RGB)
plt.imshow(p1)
plt.grid(False)
plt.show()

# %% [markdown]
# 1. We will try to process this image in order to get rid of the unnecessary pixels. Feeding this picture to the model directly will result in a target leakage. The classifier will learn the stones and the container's pixels and build its prediction upon these pixels as well. This is something we would like to avoid.
# 1.
# 1. We start our preprocessing with simply segment an object from an image based on color using OpenCV. A popular computer vision library written in C/C++ with bindings for Python, OpenCV provides easy ways of manipulating color spaces [2].

# %%
def set_size(w,h, ax=None):
    """ w, h: width, height in inches """
    if not ax: ax=plt.gca()
    l = ax.figure.subplotpars.left
    r = ax.figure.subplotpars.right
    t = ax.figure.subplotpars.top
    b = ax.figure.subplotpars.bottom
    figw = float(w)/(r-l)
    figh = float(h)/(t-b)
    ax.figure.set_size_inches(figw, figh)
    
pixel_colors = p1.reshape((np.shape(p1)[0]*np.shape(p1)[1], 3))
norm = colors.Normalize(vmin=-1.,vmax=1.)
norm.autoscale(pixel_colors)
pixel_colors = norm(pixel_colors).tolist()

# %% [markdown]
# * 2.2 Visualize the plant image in RGB color space:¶
# * Here, we visualize the small-flowered Cranesbill image we opened above in RGB space to see the distributions of the color pixels.
# *
# * RGB is considered an “additive” color space, and colors can be imagined as being produced from shining quantities of red, blue, and green light onto a black background.

# %%
r, g, b = cv2.split(p1)
fig = plt.figure()
axis = fig.add_subplot(1, 1, 1, projection="3d")
set_size(6,6)
pixel_colors = p1.reshape((np.shape(p1)[0]*np.shape(p1)[1], 3))
norm = colors.Normalize(vmin=-1.,vmax=1.)
norm.autoscale(pixel_colors)
pixel_colors = norm(pixel_colors).tolist()

axis.scatter(r.flatten(), g.flatten(), b.flatten(), facecolors=pixel_colors, marker=".")
axis.set_xlabel("Red", weight='bold')
axis.set_ylabel("Green", weight='bold')
axis.set_zlabel("Blue", weight='bold')

plt.show()

# %% [markdown]
# 1. From this plot, you can see that the green parts of the image are mixed with the red and blue values. Segmenting our plant image out in RGB space based on ranges of RGB values would not be easy.
# 1.
# 1. The solution is to try another color space, we go next with HSV color space.

# %% [markdown]
# 1. 2.3 Visualize the plant image in HSV color space:
# 1. HSV stands for Hue, Saturation, and Value (or brightness), and is a cylindrical color space. The colors, or hues, are modeled as an angular dimension rotating around a central, vertical axis, which represents the value channel. Values go from dark (0 at the bottom) to light at the top. The third axis, saturation, defines the shades of hue from least saturated, at the vertical axis, to most saturated furthest away from the center:

# %%
hsv_p1 = cv2.cvtColor(p1, cv2.COLOR_RGB2HSV)

# %%
h, s, v = cv2.split(hsv_p1)
fig = plt.figure()
axis = fig.add_subplot(1, 1, 1, projection="3d")


axis.scatter(h.flatten(), s.flatten(), v.flatten(), facecolors=pixel_colors, marker=".")
axis.set_xlabel("Hue",weight='bold')
axis.set_ylabel("Saturation", weight='bold')
axis.set_zlabel("Value", weight='bold')
set_size(6,6)
plt.show()

# %% [markdown]
# Segmentation:¶
# 3.1 Color-based segmentation:
# To pick out a range color, we can use a color picking app online [3]. I found the green color ranges in a forum:
#
# minimum green(H=36, S=25, V=25)
# maximum green(H=70, S=255,V=255)
# We will use the openCV function cv2.inRange() to try to threshold our plant image with the minimum and maximum green values.
#
# inRange() takes three parameters: the image, the lower range, and the higher range. It returns a binary mask (an ndarray of 1s and 0s) the size of the image where values of 1 indicate values within the range, and zero values indicate values outside [2].

# %%
def plot_mask(image, colormin, colormax):
        hsv_p1 = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)   
        mask = cv2.inRange(hsv_p1, colormin , colormax)
        result = cv2.bitwise_and(image, image, mask=mask)
        plt.figure(figsize=(15,10))
        plt.subplot(1, 3, 1)
        plt.imshow(image)
        plt.grid(False)
        plt.subplot(1, 3, 2)
        plt.imshow(mask, cmap="gray")
        plt.grid(False)
        plt.subplot(1, 3, 3)
        plt.imshow(result)
        plt.grid(False)
        return plt.show()

# %%
colormin=(36, 25, 25)
colormax=(70, 255,255)

plot_mask(p1, colormin, colormax)

# %% [markdown]
# The result of our initial threshold is not bad, but we are missing some pixels of the plants. We will try to play manually with the saturation and brightness values to get a better a mask.

# %%
new_colormin=(25,50,50)
new_colormax=(80,255,255)
plot_mask(p1, new_colormin, new_colormax)

# %% [markdown]
# * Great! The segmentation looks fine. We got rid of the stones and the containers pixels. Let's apply this mask on the rest of pictures and visualize the results.
# *
# * 3.2 Segmentation function:
# * Now, we create a function that applies segmentation on the rest of the images. This function will be used to feed the computer vision model with the segmented images instead of the original ones.

# %%
def segmented(image):
    foto = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    hsv_foto = cv2.cvtColor(foto, cv2.COLOR_RGB2HSV)
    #print("hsvh",hsv_foto.dtype)
    colormin=(25,50,50)
    colormax=(86,255,255)

    mask = cv2.inRange(hsv_foto, colormin , colormax)
    #print("mask",mask.dtype)
    result = cv2.bitwise_and(foto, foto, mask=mask)
    #print("result",result.dtype)
    pil_image= Image.fromarray(result)


    return result

# %% [markdown]
#  Visualize the results of segmentation on the 12 plant species

# %%
plt.figure(figsize=(15,10))

for n in range(12):
        folder = subfolders[n]
        plt.subplot(3,4,n+1)
        files = listdir(Directory + folder + "/") 
        image=cv2.imread(Directory + folder + "/" + files[n+221])
        plt.imshow(segmented(image))
        plt.axis("off")
        plt.title(folder, weight='bold', fontsize=14)

# %%
def segmented2(image):
    image=np.array(image)

    hsv_foto = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
    colormin=(25,50,50)
    colormax=(90,255,255)
    mask = cv2.inRange(hsv_foto, colormin , colormax)
    
    result = cv2.bitwise_and(image, image, mask=mask)
    result2=np.array(result)



    return result2

# %% [markdown]
# 1. Computer vision model:¶
# 1. In this section, we will try to feed those plant images to a pretrained VGG19 convolutional neural network. We will train with both original and segmented images in order to find out the impact of the target leakage on training.

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        validation_split=0.15,
        preprocessing_function = segmented2
                     )

# %%
train_generator = train_datagen.flow_from_directory(
    '../input/v2-plant-seedlings-dataset/nonsegmentedv2',
        target_size=(64,64),
        batch_size=32,
        class_mode='categorical',
        subset='training')

validation_generator = train_datagen.flow_from_directory(
        '../input/v2-plant-seedlings-dataset/nonsegmentedv2',
        target_size=(64, 64),
        batch_size=32,
        class_mode='categorical',
        subset='validation')
# Out:
# Found 4714 images belonging to 12 classes.
# Found 825 images belonging to 12 classes.

# %%
# load pre-trained weights and add global average pooling layer
#base_model_incv3 = InceptionV3(weights=weights_incv3, input_shape=(150,150,3), include_top=False, pooling='avg')

# freeze convolutional layers
#for layer in base_model_incv3.layers:
#    layer.trainable = False

#define classification layers
#x = Dense(1024, activation='relu')(base_model_incv3.output)
#predictions = Dense(1, activation='sigmoid')(x)
#x = Dense(256, activation='relu')(base_model_incv3.output)
#x = Dropout(0.5)(x)
#predictions = Dense(12, activation='softmax')(x)

#model = Model(inputs=base_model_incv3.input, outputs=predictions)
#print(model.summary())

# %%
from keras.applications.vgg19 import VGG19
from keras.layers import Dropout
from keras.models import Sequential
from keras.layers import Dense, Flatten

# %%
vgg_conv = VGG19(weights='imagenet', include_top=False,pooling='avg', input_shape=(64, 64, 3))


model = Sequential()

model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(12, activation='softmax'))

# %%
model.compile(Adam(lr=0.0001), loss='categorical_crossentropy', 
              metrics=['accuracy'])

# %%
# We'll stop training if no improvement after some epochs
earlystopper1 = EarlyStopping(monitor='loss', patience=5, verbose=1)

# Save the best model during the traning
checkpointer1 = ModelCheckpoint('best_model1.hdf5'
                                ,monitor='val_accuracy'
                                ,verbose=1
                                ,save_best_only=True
                                ,save_weights_only=True)

# %%
history = model.fit_generator(train_generator, steps_per_epoch=800, 
                    validation_data=validation_generator,
                    validation_steps=128,
                    epochs=5, verbose=1,
                   callbacks=[checkpointer1])
# Out:
# Epoch 1/5
# 148/800 [====>.........................] - ETA: 4:45 - loss: 2.4625 - accuracy: 0.1375
# Epoch 00001: val_accuracy improved from -inf to 0.13818, saving model to best_model1.hdf5
# 148/800 [====>.........................] - 78s 526ms/step - loss: 2.4625 - accuracy: 0.1375 - val_loss: 2.4531 - val_accuracy: 0.1382

# %%
plt.style.use('seaborn')
sns.set_style('whitegrid')
fig = plt.figure(figsize=(15,10))
#First Model
ax1 = plt.subplot2grid((2,2),(0,0))
train_loss = history.history['loss']
test_loss = history.history['val_loss']
x = list(range(1, len(test_loss) + 1))
plt.plot(x, test_loss, color = 'cyan', label = 'Test loss')
plt.plot(x, train_loss, label = 'Training losss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Model 1: Loss vs. Epoch',weight='bold', fontsize=18)
ax1 = plt.subplot2grid((2,2),(0,1))
train_acc = history.history['accuracy']
test_acc = history.history['val_accuracy']
x = list(range(1, len(test_acc) + 1))
plt.plot(x, test_acc, color = 'cyan', label = 'Test accuracy')
plt.plot(x, train_acc, label = 'Training accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Model 1: Accuracy vs. Epoch', weight='bold', fontsize=18)
plt.show()
